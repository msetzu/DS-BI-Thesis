# %%
import pandas as pd
import numpy as np
import ast

from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
annotated_texts_df = pd.read_csv("data/annotated_dataset/annotated_texts_repr.csv", sep=",", encoding="utf-8")

x_tfidf = annotated_texts_df["tfidf"]
x_tfidf = np.array([ast.literal_eval(item) for item in x_tfidf])

x_docembedding = annotated_texts_df["doc_embedding"]
x_docembedding = np.array([ast.literal_eval(item) for item in x_docembedding])

x_docembedding_pos = annotated_texts_df["doc_embedding_pos"]
x_docembedding_pos = np.array([ast.literal_eval(item) for item in x_docembedding_pos])

x_linguistic_profile = annotated_texts_df["linguistic_profile"]
x_linguistic_profile = np.array([ast.literal_eval(item) for item in x_linguistic_profile])

standard_reprs = {
    "tfidf": x_tfidf,
    "doc_embedding": x_docembedding,
    "doc_embedding_pos": x_docembedding_pos,
    "linguistic_profile": x_linguistic_profile
}

# %%
annotated_texts_pro_df = pd.read_csv("data/annotated_dataset/annotated_texts_repr_pro_complete.csv", sep=",", encoding="utf-8")

x_tfidf_extended = annotated_texts_pro_df["tfidf_pro"]
x_tfidf_extended = np.array([ast.literal_eval(item) for item in x_tfidf_extended])

x_docembedding_extended = annotated_texts_pro_df["doc_embedding_pro"]
x_docembedding_extended = np.array([ast.literal_eval(item) for item in x_docembedding_extended])

x_docembedding_pos_extended = annotated_texts_pro_df["docembedding_pos_pro"]
x_docembedding_pos_extended = np.array([ast.literal_eval(item) for item in x_docembedding_pos_extended])

x_linguistic_profile_extended = annotated_texts_pro_df["linguistic_profile_pro"]
x_linguistic_profile_extended = np.array([ast.literal_eval(item) for item in x_linguistic_profile_extended])

extended_reprs = {
    "tfidf": x_tfidf_extended,
    "doc_embedding": x_docembedding_extended,
    "doc_embedding_pos": x_docembedding_pos_extended,
    "linguistic_profile": x_linguistic_profile_extended
}

# %%
y_pol = annotated_texts_df["polarization"]
y_pop = annotated_texts_df["pop_sum"]
y_pop_bin = [0 if x < 2 else 1 for x in y_pop]

# %%
clf_svc = LinearSVC(C=0.1, random_state=42)

clf_rf = RandomForestClassifier(n_estimators=150, 
                             criterion='gini', 
                             max_depth=None, 
                             min_samples_split=2, 
                             min_samples_leaf=1, 
                             min_weight_fraction_leaf=0.0, 
                             max_features='sqrt', 
                             random_state=0, 
                             n_jobs=-1)

clf_lgbm = LGBMClassifier(random_state=8, verbose=-1)

models = {
    "svc": clf_svc,
    "rf": clf_rf,
    "lgbm": clf_lgbm
}

# %%
def models_x_repr(reprs, y):
    for model_name, model in models.items():
        print("-------------------")
        for rep_name, rep in reprs.items():
            print(model_name)
            print(rep_name)
            predictions = cross_val_predict(model, rep, y, cv=5)
            print(classification_report(y, predictions))

# %% [markdown]
# # Document level

# %% [markdown]
# ### Polarization - Standard repr - Document Level

# %%
models_x_repr(standard_reprs, y_pol)
# Out:
# -------------------
# svc
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.70      0.20      0.31      1651
#            1       0.65      0.79      0.72      4957
#            2       0.70      0.73      0.72      4232
#
#     accuracy                           0.68     10840
#    macro avg       0.69      0.57      0.58     10840
# weighted avg       0.68      0.68      0.65     10840
#
# svc
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1651
#            1       0.58      0.69      0.63      4957
#            2       0.56      0.64      0.60      4232
#
#     accuracy                           0.57     10840
#    macro avg       0.38      0.45      0.41     10840
# weighted avg       0.48      0.57      0.52     10840
#
# svc
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0
10840
#
# rf
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.54      0.85      0.66      3995
#            1       0.34      0.23      0.27      2371
#            2       0.17      0.00      0.00      1213
#            3       0.33      0.00      0.00       991
#            4       0.52      0.69      0.59      2270
#
#     accuracy                           0.51     10840
#    macro avg       0.38      0.35      0.31     10840
# weighted avg       0.43      0.51      0.43     10840
#
# -------------------
# lgbm
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.61      0.83      0.70      3995
#            1       0.37      0.37      0.37      2371
#            2       0.21      0.04      0.07      1213
#            3       0.16      0.03      0.05       991
#            4       0.58      0.68      0.63      2270
#
#     accuracy                           0.54     10840
#    macro avg       0.39      0.39      0.36     10840
# weighted avg       0.47      0.54      0.48     10840
#
# lgbm
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.64      0.81      0.72      3995
#            1       0.40      0.40      0.40      2371
#            2       0.18      0.05      0.08      1213
#            3       0.21      0.05      0.08       991
#            4       0.58      0.72      0.64      2270
#
#     accuracy                           0.55     10840
#    macro avg       0.40      0.41      0.38     10840
# weighted avg       0.48      0.55      0.50     10840
#
# lgbm
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0.64      0.81      0.72      3995
#            1       0.39      0.39      0.39      2371
#            2       0.19      0.06      0.09      1213
#            3       0.22      0.05      0.08       991
#            4       0.57      0.71      0.64      2270
#
#     accuracy                           0.55     10840
#    macro avg       0.40      0.41      0.38     10840
# weighted avg       0.48      0.55      0.50     10840
#
# lgbm
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.60      0.80      0.68      3995
#            1       0.35      0.34      0.34      2371
#            2       0.17      0.03      0.06      1213
#            3       0.13      0.02      0.03       991
#            4       0.54      0.68      0.60      2270
#
#     accuracy                           0.52     10840
#    macro avg       0.36      0.37      0.34     10840
# weighted avg       0.44      0.52      0.46     10840

# %% [markdown]
# ### Populism - Bin - Standard repr - Document Level

# %%
models_x_repr(standard_reprs, y_pop_bin)
# Out:
# -------------------
# svc
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85      6366
#            1       0.82      0.71      0.76      4474
#
#     accuracy                           0.82     10840
#    macro avg       0.82      0.80      0.81     10840
# weighted avg       0.82      0.82      0.81     10840
#
# svc
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.79      6366
#            1       0.73      0.59      0.65      4474
#
#     accuracy                           0.74     10840
#    macro avg       0.74      0.72      0.72     10840
# weighted avg       0.74      0.74      0.73     10840
#
# svc
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81      6366
#            1       0.75      0.64      0.69      4474
#
#     accuracy                           0.76     10840
#    macro avg       0.76      0.75      0.75     10840
# weighted avg       0.76      0.76      0.76     10840
#
# svc
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.66      0.95      0.78      6366
#            1       0.80      0.31      0.45      4474
#
#     accuracy                           0.68     10840
#    macro avg       0.73      0.63      0.61     10840
# weighted avg       0.72      0.68      0.64     10840
#
# -------------------
# rf
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.72      0.93      0.81      6366
#            1       0.84      0.49      0.62      4474
#
#     accuracy                           0.75     10840
#    macro avg       0.78      0.71      0.71     10840
# weighted avg       0.77      0.75      0.73     10840
#
# rf
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82      6366
#            1       0.77      0.67      0.71      4474
#
#     accuracy                           0.78     10840
#    macro avg       0.78      0.76      0.77     10840
# weighted avg       0.78      0.78      0.78     10840
#
# rf
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82      6366
#            1       0.77      0.67      0.71      4474
#
#     accuracy                           0.78     10840
#    macro avg       0.78      0.76      0.77     10840
# weighted avg       0.78      0.78      0.78     10840
#
# rf
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.74      0.86      0.80      6366
#            1       0.74      0.58      0.65      4474
#
#     accuracy                           0.74     10840
#    macro avg       0.74      0.72      0.72     10840
# weighted avg       0.74      0.74      0.74     10840
#
# -------------------
# lgbm
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83      6366
#            1       0.78      0.71      0.74      4474
#
#     accuracy                           0.80     10840
#    macro avg       0.79      0.78      0.79     10840
# weighted avg       0.80      0.80      0.80     10840
#
# lgbm
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82      6366
#            1       0.76      0.71      0.73      4474
#
#     accuracy                           0.79     10840
#    macro avg       0.78      0.78      0.78     10840
# weighted avg       0.79      0.79      0.79     10840
#
# lgbm
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      6366
#            1       0.76      0.70      0.73      4474
#
#     accuracy                           0.78     10840
#    macro avg       0.78      0.77      0.77     10840
# weighted avg       0.78      0.78      0.78     10840
#
# lgbm
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80      6366
#            1       0.73      0.63      0.68      4474
#
#     accuracy                           0.75     10840
#    macro avg       0.75      0.74      0.74     10840
# weighted avg       0.75      0.75      0.75     10840

# %% [markdown]
# ### Populism - Bin - Extended repr - Document Level

# %%
models_x_repr(extended_reprs, y_pop_bin)
# Out:
# -------------------
# svc
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.85      6366
#            1       0.81      0.71      0.76      4474
#
#     accuracy                           0.81     10840
#    macro avg       0.81      0.80      0.80     10840
# weighted avg       0.81      0.81      0.81     10840
#
# svc
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79      6366
#            1       0.72      0.66      0.69      4474
#
#     accuracy                           0.75     10840
#    macro avg       0.74      0.74      0.74     10840
# weighted avg       0.75      0.75      0.75     10840
#
# svc
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.81      6366
#            1       0.74      0.67      0.70      4474
#
#     accuracy                           0.77     10840
#    macro avg       0.76      0.75      0.76     10840
# weighted avg       0.77      0.77      0.77     10840
#
# svc
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.75      0.62      0.68      6366
#            1       0.57      0.71      0.63      4474
#
#     accuracy                           0.66     10840
#    macro avg       0.66      0.66      0.65     10840
# weighted avg       0.68      0.66      0.66     10840
#
# -------------------
# rf
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      6366
#            1       0.76      0.60      0.67      4474
#
#     accuracy                           0.76     10840
#    macro avg       0.76      0.73      0.74     10840
# weighted avg       0.76      0.76      0.75     10840
#
# rf
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82      6366
#            1       0.77      0.68      0.72      4474
#
#     accuracy                           0.78     10840
#    macro avg       0.78      0.77      0.77     10840
# weighted avg       0.78      0.78      0.78     10840
#
# rf
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82      6366
#            1       0.76      0.67      0.72      4474
#
#     accuracy                           0.78     10840
#    macro avg       0.78      0.76      0.77     10840
# weighted avg       0.78      0.78      0.78     10840
#
# rf
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.76      0.85      0.80      6366
#            1       0.75      0.62      0.68      4474
#
#     accuracy                           0.76     10840
#    macro avg       0.75      0.74      0.74     10840
# weighted avg       0.76      0.76      0.75     10840
#
# -------------------
# lgbm
# tfidf
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83      6366
#            1       0.78      0.70      0.74      4474
#
#     accuracy                           0.79     10840
#    macro avg       0.79      0.78      0.79     10840
# weighted avg       0.79      0.79      0.79     10840
#
# lgbm
# doc_embedding
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      6366
#            1       0.77      0.72      0.74      4474
#
#     accuracy                           0.79     10840
#    macro avg       0.79      0.78      0.79     10840
# weighted avg       0.79      0.79      0.79     10840
#
# lgbm
# doc_embedding_pos
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      6366
#            1       0.76      0.71      0.74      4474
#
#     accuracy                           0.79     10840
#    macro avg       0.79      0.78      0.78     10840
# weighted avg       0.79      0.79      0.79     10840
#
# lgbm
# linguistic_profile
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81      6366
#            1       0.74      0.67      0.70      4474
#
#     accuracy                           0.77     10840
#    macro avg       0.76      0.75      0.76     10840
# weighted avg       0.76      0.77      0.76     10840
